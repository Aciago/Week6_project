# %% [markdown]
# # Week 6, Models project

# %% [raw]
# what to do:
#     - get data
#     - clean it
#     - exploratory analysis \ visualize it
#     - build some models
#     - do some feature engineering
#     - re-build model
#     - compare results
#
# https://www.kaggle.com/lucabasa/dutch-energy
# https://www.kaggle.com/rajeevw/ufcdata
#
# http://localhost:8889/notebooks/ih/Jan2020_EverydayCode/Week_7/Day3.ipynb
#
# comparison tables
# graphics for individual models
# PCA works only for numerical data (due to it's measuring covariance)
# VIF?
#
# logloss
# auc graphs
# pca
# decision tree graph
#
#
# https://docs.google.com/presentation/d/1Ah4uQieDDd7Pea-3Qq8g3aGb7Jbg6-fq3i5oF1r9PRc/edit#slide=id.g6f17c6835e_0_7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.options.display.max_columns = None
pd.set_option('display.max_rows', 200)

# %% [markdown]
# # MMA db

# %%
dft = pd.read_csv(r"C:/Users/aciag/ih/Week6_project/data/ufcdata/preprocessed_data.csv")

# %%
dft.head()
# Out:
#   Winner  title_bout  no_of_rounds  B_current_lose_streak  \
# 0    Red        True             5                    0.0
# 1    Red        True             5                    0.0
# 2    Red       False             3                    0.0
# 3   Blue       False             3                    0.0
# 4   Blue       False             3                    0.0
#
#    B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 0                   4.0     0.0        9.200000           6.000000
# 1                   3.0     0.0       14.600000           9.100000
# 2                   3.0     0.0       15.354839          11.322581
# 3                   4.0     0.0       17.000000          14.000000
# 4                   1.0     0.0       17.000000          14.500000
#
#    B_avg_CLINCH_att  B_avg_CLINCH_landed  B_avg_DISTANCE_att  \
# 0          0.200000             0.000000           62.600000
# 1         11.800000             7.300000          124.700000
# ...

# %%
# reading data from the file
df = pd.read_csv(r"C:/Users/aciag/ih/Week6_project/data/ufcdata/data.csv")

# %%
df.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  B_current_win_streak  B_draw  B_avg_BODY_att  \
# ...

# %%
df.shape
# Out:
# (5144, 145)

# %%
df.tail(3)
# Out:
#            R_fighter      B_fighter               Referee        date  \
# 5141    Royce Gracie  Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142    Kevin Rosier   Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143  Gerard Gordeau     Teila Tuli  Joao Alberto Barreto  1993-11-12
#
#                    location Winner  title_bout weight_class  no_of_rounds  \
# 5141  Denver, Colorado, USA    Red       False  Open Weight             1
# 5142  Denver, Colorado, USA    Red       False  Open Weight             1
# 5143  Denver, Colorado, USA    Red       False  Open Weight             1
#
#       B_current_lose_streak  B_current_win_streak  B_draw  B_avg_BODY_att  \
# 5141                    0.0                   0.0     0.0             NaN
# 5142                    0.0                   0.0     0.0             NaN
# 5143                    0.0                   0.0     0.0             NaN
#
#       B_avg_BODY_landed  B_avg_CLINCH_att  B_avg_CLINCH_landed  \
# ...

# %%
df.shape
# Out:
# (5144, 145)

# %%
df.dtypes
# Out:
# R_fighter                        object
# B_fighter                        object
# Referee                          object
# date                             object
# location                         object
# Winner                           object
# title_bout                         bool
# weight_class                     object
# no_of_rounds                      int64
# B_current_lose_streak           float64
# B_current_win_streak            float64
# B_draw                          float64
# B_avg_BODY_att                  float64
# B_avg_BODY_landed               float64
# B_avg_CLINCH_att                float64
# B_avg_CLINCH_landed             float64
# B_avg_DISTANCE_att              float64
# B_avg_DISTANCE_landed           float64
# B_avg_GROUND_att                float64
# B_avg_GROUND_landed             float64
# B_avg_HEAD_att                  float64
# B_avg_HEAD_landed               float64
# B_avg_KD                        float64
# ...

# %%
df.Winner.value_counts()
# Out:
# Red     3470
# Blue    1591
# Draw      83
# Name: Winner, dtype: int64

# %%
# viz of initial data, distribution of winning color
sns.set(style='darkgrid', color_codes=True, rc={'figure.figsize':(10,5)})
sns.countplot('Winner', data=df, palette="Reds_r")

plt.show();

# %%
sns.set(style='darkgrid', color_codes=True, rc={'figure.figsize':(15,8)})
sns.scatterplot(y='weight_class', x=(df.R_Weight_lbs+df.B_Weight_lbs)/2 ,data=df)

plt.show();

# %%
# viz of fighters average age and amount of rounds to decide a winner

sns.set(rc={'figure.figsize':(20,10)})
sns.boxplot(x='no_of_rounds',
            y=(df.R_age+df.B_age)/2,
            hue='weight_class',
            width=2,
            orient='v',
            data=df);
plt.show()

# %% [markdown]
# ### Clean and preprocess the data

# %%
# dropping all draw outcomes from the dataset
df.drop(df.loc[df['Winner']=='Draw'].index, inplace=True)

# %%
# drop NA
df.isna().sum()
# Out:
# R_fighter                          0
# B_fighter                          0
# Referee                           22
# date                               0
# location                           0
# Winner                             0
# title_bout                         0
# weight_class                       0
# no_of_rounds                       0
# B_current_lose_streak              0
# B_current_win_streak               0
# B_draw                             0
# B_avg_BODY_att                  1241
# B_avg_BODY_landed               1241
# B_avg_CLINCH_att                1241
# B_avg_CLINCH_landed             1241
# B_avg_DISTANCE_att              1241
# B_avg_DISTANCE_landed           1241
# B_avg_GROUND_att                1241
# B_avg_GROUND_landed             1241
# B_avg_HEAD_att                  1241
# B_avg_HEAD_landed               1241
# B_avg_KD                        1241
# B_avg_LEG_att                   1241
# B_avg_LEG_landed                1241
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#            R_fighter          B_fighter               Referee        date  \
# 5     Tatiana Suarez      Nina Ansaroff       Robert Madrigal  2019-06-08
# 11    Eddie Wineland     Grigorii Popov       Kevin MacDonald  2019-06-08
# 17     Daniel Teymur        Sung Bin Jo           Rebin Saber  2019-06-01
# 18      Rostem Akman  Sergey Khandozhko          Leon Roberts  2019-06-01
# 22       Bea Malecki       Duda Santana                   NaN  2019-06-01
# ...              ...                ...                   ...         ...
# 5139  Gerard Gordeau       Kevin Rosier  Joao Alberto Barreto  1993-11-12
# 5140    Ken Shamrock      Patrick Smith  Joao Alberto Barreto  1993-11-12
# 5141    Royce Gracie      Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142    Kevin Rosier       Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143  Gerard Gordeau         Teila Tuli  Joao Alberto Barreto  1993-11-12
#
#                     location Winner  title_bout          weight_class  \
# ...

# %%
df = df.dropna(axis=0, how='any')
df.isna().sum()
# Out:
# R_fighter                       0
# B_fighter                       0
# Referee                         0
# date                            0
# location                        0
# Winner                          0
# title_bout                      0
# weight_class                    0
# no_of_rounds                    0
# B_current_lose_streak           0
# B_current_win_streak            0
# B_draw                          0
# B_avg_BODY_att                  0
# B_avg_BODY_landed               0
# B_avg_CLINCH_att                0
# B_avg_CLINCH_landed             0
# B_avg_DISTANCE_att              0
# B_avg_DISTANCE_landed           0
# B_avg_GROUND_att                0
# B_avg_GROUND_landed             0
# B_avg_HEAD_att                  0
# B_avg_HEAD_landed               0
# B_avg_KD                        0
# B_avg_LEG_att                   0
# B_avg_LEG_landed                0
# B_avg_PASS                      0
# B_avg_REV                       0
# ...

# %%
#dummies for winner and title_bout col
#df = pd.get_dummies(data=df, columns=['Winner'], drop_first=True)
#df = pd.get_dummies(data=df, columns=['title_bout'], drop_first=True)

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3151 entries, 0 to 5008
# Data columns (total 145 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   R_fighter                     object
#  1   B_fighter                     object
#  2   Referee                       object
#  3   date                          object
#  4   location                      object
#  5   Winner                        object
#  6   title_bout                    bool
#  7   weight_class                  object
#  8   no_of_rounds                  int64
#  9   B_current_lose_streak         float64
#  10  B_current_win_streak          float64
#  11  B_draw                        float64
#  12  B_avg_BODY_att                float64
#  13  B_avg_BODY_landed             float64
#  14  B_avg_CLINCH_att              float64
#  15  B_avg_CLINCH_landed           float64
#  16  B_avg_DISTANCE_att            float64
#  17  B_avg_DISTANCE_landed         float64
# ...

# %%
# change dtypes to sklearn-readable type (string)

df['Referee'] = df['Referee'].astype("string")
df['location'] = df['location'].astype("string")
df['R_fighter'] = df['R_fighter'].astype("string")
df['B_fighter'] = df['B_fighter'].astype("string")
df['R_Stance'] = df['R_Stance'].astype("string")
df['B_Stance'] = df['B_Stance'].astype("string")
df['Winner'] = df['Winner'].astype("string")
df['weight_class'] = df['weight_class'].astype("string")

# %%
# turn non-numeric data into numeric (dummies)

df['R_fighter'] = le.fit_transform(df['R_fighter'])
df['B_fighter'] = le.fit_transform(df['B_fighter'])
df['location'] = le.fit_transform(df['location'])
df['weight_class'] = le.fit_transform(df['weight_class'])

df['Referee'] = le.fit_transform(df['Referee'])
df['B_Stance'] = le.fit_transform(df['B_Stance'])
df['R_Stance'] = le.fit_transform(df['R_Stance'])

df['Winner'] = le.fit_transform(df['Winner'])
df['title_bout'] = le.fit_transform(df['title_bout'])

# %%
# dropping irrelevant columns
df.drop(columns=['date'],axis=1,inplace=True)

# %%
#dummies for winner col
#df4 = pd.get_dummies(data=df4, columns=['Winner','R_Stance','B_Stance','title_bout'], drop_first=True)

# %%
df.head(15)
# Out:
#     R_fighter  B_fighter  Referee  location  Winner  title_bout  weight_class  \
# 0         312        666      101        32       1           1             0
# 1         826        465      140        32       1           1            11
# 2         813        281       27        32       1           0             6
# 3         383        796       86        32       0           0             0
# 4         776        102       27        32       0           0             4
# 6          36        793      101        32       1           0             0
# 7         459         34       86        32       0           0            12
# 8         677        137       27        32       0           0             2
# 9         854         63      140        32       1           0            12
# 10         79        244      101        32       0           0             7
# 12        460        477       27        32       1           0            11
# ...

# %% [markdown]
# ### Training

# %%
data = df.drop(columns=['Winner'])
target = df['Winner']

# %%
from sklearn.model_selection import train_test_split

# %%
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.20, random_state = 42)

# %% [markdown]
# ### Models

# %%
# NBayes
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score
from sklearn.metrics import auc,confusion_matrix

from sklearn.metrics import roc_auc_score, roc_curve

# %%
gnb = GaussianNB()
model1 = gnb.fit(data_train, target_train).predict(data_test)
print("NBayes accuracy is ", accuracy_score(target_test, model1, normalize=True))
# Out:
# NBayes accuracy is  0.6038034865293186

# %%
conf1=confusion_matrix(target_test,model1)
conf1
# Out:
# array([[149,  91],
#        [159, 232]], dtype=int64)

# %%
model1_roc=roc_auc_score(target_test,model1)
fpr,tpr,thresholds=roc_curve(target_test, gnb.predict_proba(data_test)[:,1])

plt.figure()
plt.plot(fpr,tpr,label=f'Model1 (area={model1_roc})')
plt.plot([0,1],[0,1])
plt.legend()
plt.show()

# %%
#LinearSVC
from sklearn.svm import LinearSVC
#from sklearn.metrics import accuracy_score

# %%
svc_model = LinearSVC(max_iter=10000, random_state=42)
model2 = svc_model.fit(data_train, target_train).predict(data_test)
print("LinearSVC acciracy is ", accuracy_score(target_test, model2, normalize=True))
# Out:
# LinearSVC acciracy is  0.6259904912836767
# C:\Users\aciag\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
conf2=confusion_matrix(target_test,model2)
conf2
# Out:
# array([[ 10, 230],
#        [  6, 385]], dtype=int64)

# %%
# KNeighbors
from sklearn.neighbors import KNeighborsClassifier
#from sklearn.metrics import accuracy_score

# %%
knb = KNeighborsClassifier(n_neighbors=25)
knb.fit(data_train, target_train)
model3 = knb.predict(data_test)
print("KNeighbors accuracy is ", accuracy_score(target_test, model3))
# Out:
# KNeighbors accuracy is  0.6228209191759112

# %%
conf3=confusion_matrix(target_test,model3)
conf3
# Out:
# array([[ 33, 207],
#        [ 31, 360]], dtype=int64)

# %%
model3_roc=roc_auc_score(target_test,model3)
fpr,tpr,thresholds=roc_curve(target_test, knb.predict_proba(data_test)[:,1])

plt.figure()
plt.plot(fpr,tpr,label=f'Model3 (area={model3_roc})')
plt.plot([0,1],[0,1])
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
model4=LogisticRegression(max_iter=10000, solver='liblinear')
res4=model4.fit(data_train,target_train)
pred4=model4.predict(data_test)

print("LogisticRegression accuracy is ", accuracy_score(target_test, pred4))
# Out:
# LogisticRegression accuracy is  0.6687797147385103

# %%
conf4=confusion_matrix(target_test,pred4)
conf4

#pd.DataFrame(pred4).head()
# Out:
# array([[ 87, 153],
#        [ 56, 335]], dtype=int64)

# %%
model4_roc=roc_auc_score(target_test,pred4)
fpr,tpr,thresholds=roc_curve(target_test, model4.predict_proba(data_test)[:,1])

plt.figure()
plt.plot(fpr,tpr,label=f'Model4 (area={model4_roc})')
plt.plot([0,1],[0,1])
plt.legend()
plt.show()

# %%
# plot AUC ROC curve qnd get the AUC score and log loss

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model5=DecisionTreeClassifier(class_weight='balanced')
res5=model5.fit(data_train,target_train)
pred5=model5.predict(data_test)

print("DecisionTreeClassifier accuracy is ", accuracy_score(target_test, pred5))
# Out:
# DecisionTreeClassifier accuracy is  0.5705229793977813

# %%
conf5=confusion_matrix(target_test,pred5)
conf5
# Out:
# array([[ 94, 146],
#        [125, 266]], dtype=int64)

# %%
model5_roc=roc_auc_score(target_test,pred5)
fpr,tpr,thresholds=roc_curve(target_test, model5.predict_proba(data_test)[:,1])

plt.figure()
plt.plot(fpr,tpr,label=f'Model5 (area={model5_roc})')
plt.plot([0,1],[0,1])
plt.legend()
plt.show()

# %%
# try to plot your tree

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model6=RandomForestClassifier(class_weight='balanced')
res6=model6.fit(data_train,target_train)
pred6=model6.predict(data_test)

print("RandomForestClassifier accuracy is ", accuracy_score(target_test, pred6))
# Out:
# RandomForestClassifier accuracy is  0.6465927099841522

# %%
conf6=confusion_matrix(target_test,pred6)
conf6
# Out:
# array([[ 42, 198],
#        [ 25, 366]], dtype=int64)

# %%
model6_roc=roc_auc_score(target_test,pred6)
fpr,tpr,thresholds=roc_curve(target_test, model6.predict_proba(data_test)[:,1])

plt.figure()
plt.plot(fpr,tpr,label=f'Model6 (area={model6_roc})')
plt.plot([0,1],[0,1])
plt.legend()
plt.show()

# %%
from sklearn.svm import SVC

# %%
model7=SVC(probability=True)
res7=model7.fit(data_train, target_train)
pred7=model7.predict(data_test)

print("SVC accuracy is ", accuracy_score(target_test, pred7))
# Out:
# SVC accuracy is  0.6196513470681458

# %%
conf7=confusion_matrix(target_test,pred7)
conf7
# Out:
# array([[  0, 240],
#        [  0, 391]], dtype=int64)

# %%
model7_roc=roc_auc_score(target_test,pred7)
fpr,tpr,thresholds=roc_curve(target_test, model7.predict_proba(data_test)[:,1])

plt.figure()
plt.plot(fpr,tpr,label=f'Model7 (area={model7_roc})')
plt.plot([0,1],[0,1])
plt.legend()
plt.show()

# %%
from sklearn.svm import NuSVC

# %%
model8=NuSVC(nu=0.2,probability=True, gamma='scale')
res8=model8.fit(data_train,target_train)
pred8=model8.predict(data_test)

print("SVC accuracy is ", accuracy_score(target_test, pred8))
# Out:
# SVC accuracy is  0.5530903328050714

# %%
conf8=confusion_matrix(target_test,pred8)
conf8
# Out:
# array([[ 77, 163],
#        [119, 272]], dtype=int64)

# %%
model8_roc=roc_auc_score(target_test,pred8)
fpr,tpr,thresholds=roc_curve(target_test, model8.predict_proba(data_test)[:,1])

plt.figure()
plt.plot(fpr,tpr,label=f'Model8 (area={model8_roc})')
plt.plot([0,1],[0,1])
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# %%
print(accuracy_score(target_test, model1))
print(accuracy_score(target_test, model2))
print(accuracy_score(target_test, model3))
print(accuracy_score(target_test, pred4))
print(accuracy_score(target_test, pred5))
print(accuracy_score(target_test, pred6))
print(accuracy_score(target_test, pred7))
print(accuracy_score(target_test, pred8))
# Out:
# 0.6038034865293186
# 0.6259904912836767
# 0.6228209191759112
# 0.6687797147385103
# 0.5705229793977813
# 0.6465927099841522
# 0.6196513470681458
# 0.5530903328050714

# %%
print(recall_score(target_test, model1))
print(recall_score(target_test, model2))
print(recall_score(target_test, model3))
print(recall_score(target_test, pred4))
print(recall_score(target_test, pred5))
print(recall_score(target_test, pred6))
print(recall_score(target_test, pred7))
print(recall_score(target_test, pred8))
# Out:
# 0.5933503836317136
# 0.9846547314578005
# 0.9207161125319693
# 0.8567774936061381
# 0.680306905370844
# 0.9360613810741688
# 1.0
# 0.6956521739130435

# %%
print(precision_score(target_test, model1))
print(precision_score(target_test, model2))
print(precision_score(target_test, model3))
print(precision_score(target_test, pred4))
print(precision_score(target_test, pred5))
print(precision_score(target_test, pred6))
print(precision_score(target_test, pred7))
print(precision_score(target_test, pred8))
# Out:
# 0.718266253869969
# 0.6260162601626016
# 0.6349206349206349
# 0.6864754098360656
# 0.6456310679611651
# 0.648936170212766
# 0.6196513470681458
# 0.6252873563218391

# %%
print(f1_score(target_test, model1))
print(f1_score(target_test, model2))
print(f1_score(target_test, model3))
print(f1_score(target_test, pred4))
print(f1_score(target_test, pred5))
print(f1_score(target_test, pred6))
print(f1_score(target_test, pred7))
print(f1_score(target_test, pred8))
# Out:
# 0.6498599439775911
# 0.7654075546719681
# 0.7515657620041754
# 0.7622298065984073
# 0.6625155666251556
# 0.7664921465968586
# 0.7651663405088063
# 0.6585956416464891

# %%
print(model1_roc)
print(model2_roc)
print(model3_roc)
print(model4_roc)
print(model5_roc)
print(model6_roc)
print(model7_roc)
print(model8_roc)
# Out:
# 0.6070918584825234
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-54cdd93e4a15> in <module>
#       1 print(model1_roc)
# ----> 2 print(model2_roc)
#       3 print(model3_roc)
#       4 print(model4_roc)
#       5 print(model5_roc)
#
# NameError: name 'model2_roc' is not defined

# %% [markdown]
# ### Comparisons

# %%
#!pip install yellowbrick

# %%
from sklearn.metrics import roc_auc_score, roc_curve
from yellowbrick.classifier import ClassificationReport

# %%
#viz gaussNB

visualizer = ClassificationReport(gnb, classes=["Red wins","Blue wins"])
visualizer.fit(data_train, target_train)
visualizer.score(data_test, target_test)
g = visualizer.poof()

# %%
# viz LinSVC
visualizer = ClassificationReport(svc_model, classes=["Red wins","Blue wins"])
visualizer.fit(data_train, target_train)
visualizer.score(data_test, target_test)
g = visualizer.poof()

# %%
# viz KNeighbors
visualizer = ClassificationReport(knb, classes=["Red wins","Blue wins"])
visualizer.fit(data_train, target_train)
visualizer.score(data_test, target_test)
g = visualizer.poof()

# %%
# viz LogisticRegression
visualizer = ClassificationReport(model4, classes=["Red wins","Blue wins"])
visualizer.fit(data_train, target_train)
visualizer.score(data_test, target_test)
g = visualizer.poof()

# %%
# viz RandomForest
visualizer = ClassificationReport(model5, classes=["Red wins","Blue wins"])
visualizer.fit(data_train, target_train)
visualizer.score(data_test, target_test)
g = visualizer.poof()

# %%
# viz SVC
visualizer = ClassificationReport(model6, classes=["Red wins","Blue wins"])
visualizer.fit(data_train, target_train)
visualizer.score(data_test, target_test)
g = visualizer.poof()

# %%
# viz NuSVC
visualizer = ClassificationReport(model7, classes=["Red wins","Blue wins"])
visualizer.fit(data_train, target_train)
visualizer.score(data_test, target_test)
g = visualizer.poof()

# %%
#import statsmodels.api as sm
#from statsmodels.tools.tools import add_constant
